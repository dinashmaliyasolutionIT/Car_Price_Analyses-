# %%
# !pip install pypdf2
# !pip install python-docx
# !pip install pytesseract
# !pip install pillow

# %%
import os
import PyPDF2
import docx
import pytesseract
from PIL import Image

# Set up the Tesseract executable path (if needed)
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'  # Adjust this path if needed

def extract_text_from_pdf(pdf_path):
    """Extract text from a PDF file."""
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        text = ""
        for page_num in range(len(reader.pages)):
            page = reader.pages[page_num]
            text += page.extract_text()
        return text

def extract_text_from_docx(docx_path):
    """Extract text from a DOCX file."""
    doc = docx.Document(docx_path)
    text = ""
    for para in doc.paragraphs:
        text += para.text + '\n'
    return text

def extract_text_from_image(image_path):
    """Extract text from an image using Tesseract OCR."""
    image = Image.open(image_path)
    text = pytesseract.image_to_string(image)
    return text

def extract_text_from_cv(cv_path):
    """Determine file type and extract text accordingly."""
    file_extension = cv_path.split('.')[-1].lower()

    if file_extension == 'pdf':
        return extract_text_from_pdf(cv_path)
    elif file_extension == 'docx':
        return extract_text_from_docx(cv_path)
    elif file_extension in ['jpg', 'jpeg', 'png', 'tiff', 'bmp']:
        return extract_text_from_image(cv_path)
    else:
        raise ValueError("Unsupported file format")

def save_extracted_text(text, output_file):
    """Save the extracted text to a text file."""
    with open(output_file, 'w', encoding='utf-8') as file:
        file.write(text)

# Example usage
if __name__ == "__main__":
    # Example CV paths (change these paths to your files)
    cv_path = '/content/Dinash_Maliya_CV (1).pdf'  # or '.docx', '.jpg', '.png'

    try:
        extracted_text = extract_text_from_cv(cv_path)
        print("Extracted Text:\n", extracted_text)

        # Optionally, save the extracted text to a file
        output_file = 'extracted_cv_text.txt'
        save_extracted_text(extracted_text, output_file)
        print(f"Extracted text saved to {output_file}")

    except Exception as e:
        print(f"Error: {e}")
# Out:
# Extracted Text:
#
#
#
#
#
#
#  SKILLS
# • Pyhton  Developer  (AI, ML, DL)
# • Office  Automation
# • Graphic  Designing
# • Computerized  Accounting
# • Web  Designing
# • Web  Development
# • Graphic Designing
# • Study  and Research  for Learning
#
#
#  EDUCATION
# • M.Phil  in CS (Progress)  from  Maju
# • BSCS  4th year,  PRESTON  UNIVERSITY
# (2016 -2020)
# • Intermediate  in Science,  Karachi  Board
# (2010 -2012)
# • Diploma  in Information  Technology  (DIT)
# from Karachi SBTE (2009 -2010)
# • ACCpro  from  Aptech  Garden  Karachi
# Board  (2014 -2017)
#
#  CERTIFICATION
# • Certificate  of appreciation  from
# MBCCS
# • Certificate  of appreciation  from
# KPS School
# • Cambridge  O'Level  Certification  (2020)   WORK  HISTORY
#
# NED UNIVERSITY   (2024 -PRESENT)
# • Visiting  Lecturer  of PITB -Program
# • Taught  Undergraduate  courses  in Skill Development
#
# DADABHOY  INSTITUTE  OF HIGHER  EDUCATION
# (2024 -PRESENT)
# • Visiting  Lecturer  of Computer  Science
# ...

# %%
import PyPDF2

# Function to extract text from a PDF file
def extract_text_from_pdf(pdf_path):
    try:
        # Open the PDF file in read-binary mode
        with open(pdf_path, 'rb') as file:
            # Create a PDF reader object
            pdf_reader = PyPDF2.PdfReader(file)

            # Initialize an empty string to store the text
            text = ""

            # Loop through all the pages and extract text
            for page_num in range(len(pdf_reader.pages)):
                page = pdf_reader.pages[page_num]
                text += page.extract_text()  # Extract text from each page

            return text
    except Exception as e:
        return f"Error: {e}"

# Example usage
if __name__ == "__main__":
    # Replace with the path to your PDF file
    pdf_path = input("Enter the path to your PDF file: ")

    # Extract the text from the PDF
    extracted_text = extract_text_from_pdf(pdf_path)

    # Print the extracted text
    print("\nExtracted Text from PDF:")
    print(extracted_text)
# Out:
# Enter the path to your PDF file: /content/Dinash_Maliya_CV (1).pdf
#
# Extracted Text from PDF:
#
#
#
#
#
#
#  SKILLS
# • Pyhton  Developer  (AI, ML, DL)
# • Office  Automation
# • Graphic  Designing
# • Computerized  Accounting
# • Web  Designing
# • Web  Development
# • Graphic Designing
# • Study  and Research  for Learning
#
#
#  EDUCATION
# • M.Phil  in CS (Progress)  from  Maju
# • BSCS  4th year,  PRESTON  UNIVERSITY
# (2016 -2020)
# • Intermediate  in Science,  Karachi  Board
# (2010 -2012)
# • Diploma  in Information  Technology  (DIT)
# from Karachi SBTE (2009 -2010)
# • ACCpro  from  Aptech  Garden  Karachi
# Board  (2014 -2017)
#
#  CERTIFICATION
# • Certificate  of appreciation  from
# MBCCS
# • Certificate  of appreciation  from
# KPS School
# • Cambridge  O'Level  Certification  (2020)   WORK  HISTORY
#
# NED UNIVERSITY   (2024 -PRESENT)
# • Visiting  Lecturer  of PITB -Program
# • Taught  Undergraduate  courses  in Skill Development
#
# ...
